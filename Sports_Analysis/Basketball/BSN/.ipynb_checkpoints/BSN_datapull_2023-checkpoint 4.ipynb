# %%
# Importing the necessary modules. 
import os
import csv
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # BSN calendar pull
#
# 1. Define a list of team numbers and names:
#
# https://bsnpr.com/juegos/juego?cid=29382&r=BS         2022 10 35

# %%
# Define a list of team numbers and names

def boxscore_scrape(year, month, day):
    try:
        date_str = f"{year}{str(month).rjust(2, '0')}{str(day).rjust(2, '0')}"
        #f"{year}{month}{str(day).rjust(2, '0')}"
        url = 'https://bsnpr.com/juegos/juego?r=BS' + str(date_str)
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        tables = soup.findAll("table", class_="tabla_stats")
        
        if len(tables) < 2:
            print(f"No boxscore found for date {date_str}")
        else:
            t_boxscore = tables[1]
            t_hometeam = tables[2]
            t_awayteam = tables[3]
              
            folder_path = f"/Users/jeanzayas/Desktop/Divergence/Portfolio/Sports Analysis/Basketball/BSN/dataset/{year}"
            if not os.path.exists(folder_path):
                os.makedirs(folder_path)

            # extract the team names and scores from the table_boxscore
            team_names = []
            team_scores = []
            for row in t_boxscore.findAll("tr")[1:]:
                cols = row.findAll("td")
                team_names.append(cols[0].text.strip())
                team_scores.append(cols[-1].text.strip())

            # Extract the table data
            table_data = []
            for row in t_boxscore.findAll("tr")[1:]:
                cols = row.findAll("td")[1:-1]
                row_data = [col.text.strip() for col in cols]
                table_data.append(row_data)

            df_table = pd.DataFrame(table_data[:4], columns=['1Q', '2Q', '3Q', '4Q'])
            ## Check if the boxscore has at least 4 quarters
            if len(table_data) > 4:
                # Create a DataFrame from the table data with 4 columns for the first 4 quarters

                # If there are more than 4 quarters, add an 'OT' column for each additional quarter
                for i in range(5, len(table_data)):
                    column_name = f"OT{i-3}"  # Name the column 'OT5' for the 5th quarter, 'OT6' for the 6th, and so on
                    df_table[column_name] = table_data[i]

            # Add the boxscore to the list of errors if it doesn't have at least 4 quarters
            else:
                # Create a DataFrame for the team names and scores 
                df_team = pd.DataFrame({'Team': team_names, 'Total': team_scores})

                # Concatenate the two DataFrames
                df = pd.concat([df_team, df_table], axis=1)
                df.drop(2, inplace=True)
                # Extract the team names and scores from the DataFrame
                home_team = df.iloc[0]['Team']
                home_score = df.iloc[0]['Total']
                away_team = df.iloc[1]['Team']
                away_score = df.iloc[1]['Total']

                # Print the final score in the desired format
                print(f"{home_team} {home_score} v {away_team} {away_score}")

                #print(df)

            # Extract the table data fro the home team
            table_data_home = []
            for row in t_hometeam.findAll("tr")[1:]:
                cols = row.findAll("td")
                row_data = [col.text.strip() for col in cols]
                table_data_home.append(row_data)

            # Create a DataFrame for the home team stats
            df_home = pd.DataFrame(table_data_home, columns=['', 'Name', 'Min', 'M', 'A', 'FG%', 'M', 'A', '3P%', 'M', 'A', 'FT%', 'O', 'D', 'T', 'AS', 'PF', 'TO', 'ST', 'BS', 'PTS'])
            
            # Extract the table data fro the away team
            table_data_away = []
            for row in t_awayteam.findAll("tr")[1:]:
                cols = row.findAll("td")
                row_data = [col.text.strip() for col in cols]
                table_data_away.append(row_data)

            # Create a DataFrame for the away team stats
            df_away = pd.DataFrame(table_data_away, columns=['', 'Name', 'Min', 'M', 'A', 'FG%', 'M', 'A', '3P%', 'M', 'A', 'FT%', 'O', 'D', 'T', 'AS', 'PF', 'TO', 'ST', 'BS', 'PTS'])

            # Remove the first empty column
            df_home.drop(df_home.columns[0], axis=1, inplace=True)
            df_away.drop(df_away.columns[0], axis=1, inplace=True)

            # Combine the team stats into one DataFrame
            df_team_stats = pd.concat([df_home, df_away])

            # Create a DataFrame for the team names and scores 
            #df_team = pd.DataFrame({'Team': team_names, 'Total': team_scores})

            # Concatenate the three DataFrames
            #df = pd.concat([df_team, df_table, df_team_stats], axis=1)
            #df.drop(2, inplace=True)
            
          

            df.to_csv(f"/Users/jeanzayas/Desktop/Divergence/Portfolio/Sports Analysis/Basketball/BSN/dataset/{year}/{date_str}_boxscore.csv", index=False)

            df_home.to_csv(f"/Users/jeanzayas/Desktop/Divergence/Portfolio/Sports Analysis/Basketball/BSN/dataset/{year}/{date_str}_home.csv", index=False)
            df_away.to_csv(f"/Users/jeanzayas/Desktop/Divergence/Portfolio/Sports Analysis/Basketball/BSN/dataset/{year}/{date_str}_away.csv", index=False)

           
    except Exception as e:
        print(f"Error: {e}")

# %%
for year in range(2023, 2024):
    for month in range(10, 13):    
        for day in range(1, 100):
            try:
                boxscore_scrape(year,month,day)
                print(f"Successfully scraped boxscore for {year}-{month}-{day}")
                
            except Exception as e:
                print(f"Error: {e}, -{year}-{month}-{day}")
# Out:
# No boxscore found for date 20071001
# Successfully scraped boxscore for 2007-10-1
# No boxscore found for date 20071002
# Successfully scraped boxscore for 2007-10-2
# No boxscore found for date 20071003
# Successfully scraped boxscore for 2007-10-3
# No boxscore found for date 20071004
# Successfully scraped boxscore for 2007-10-4
# No boxscore found for date 20071005
# Successfully scraped boxscore for 2007-10-5
# No boxscore found for date 20071006
# Successfully scraped boxscore for 2007-10-6
# No boxscore found for date 20071007
# Successfully scraped boxscore for 2007-10-7
# No boxscore found for date 20071008
# Successfully scraped boxscore for 2007-10-8
# No boxscore found for date 20071009
# Successfully scraped boxscore for 2007-10-9
# No boxscore found for date 20071010
# Successfully scraped boxscore for 2007-10-10
# No boxscore found for date 20071011
# Successfully scraped boxscore for 2007-10-11
# No boxscore found for date 20071012
# Successfully scraped boxscore for 2007-10-12
# No boxscore found for date 20071013
# Successfully scraped boxscore for 2007-10-13
# No boxscore found for date 20071014
# Successfully scraped boxscore for 2007-10-14
# No boxscore found for date 20071015
# Successfully scraped boxscore for 2007-10-15
# No boxscore found for date 20071016
# Successfully scraped boxscore for 2007-10-16
# No boxscore found for date 20071017
# Successfully scraped boxscore for 2007-10-17
# No boxscore found for date 20071018
# Successfully scraped boxscore for 2007-10-18
# No boxscore found for date 20071019
# Successfully scraped boxscore for 2007-10-19
# No boxscore found for date 20071020
# Successfully scraped boxscore for 2007-10-20
# No boxscore found for date 20071021
# Successfully scraped boxscore for 2007-10-21
# No boxscore found for date 20071022
# Successfully scraped boxscore for 2007-10-22
# No boxscore found for date 20071023
# Successfully scraped boxscore for 2007-10-23
# No boxscore found for date 20071024
# Successfully scraped boxscore for 2007-10-24
# No boxscore found for date 20071025
# Successfully scraped boxscore for 2007-10-25
# No boxscore found for date 20071026
# Successfully scraped boxscore for 2007-10-26
# No boxscore found for date 20071027
# Successfully scraped boxscore for 2007-10-27
# No boxscore found for date 20071028
# Successfully scraped boxscore for 2007-10-28
# No boxscore found for date 20071029
# Successfully scraped boxscore for 2007-10-29
# No boxscore found for date 20071030
# Successfully scraped boxscore for 2007-10-30
# No boxscore found for date 20071031
# Successfully scraped boxscore for 2007-10-31
# No boxscore found for date 20071032
# Successfully scraped boxscore for 2007-10-32
# No boxscore found for date 20071033
# Successfully scraped boxscore for 2007-10-33
# No boxscore found for date 20071034
# Successfully scraped boxscore for 2007-10-34
# No boxscore found for date 20071035
# Successfully scraped boxscore for 2007-10-35
# No boxscore found for date 20071036
# Successfully scraped boxscore for 2007-10-36
# No boxscore found for date 20071037
# Successfully scraped boxscore for 2007-10-37
# No boxscore found for date 20071038
# Successfully scraped boxscore for 2007-10-38
# No boxscore found for date 20071039
# Successfully scraped boxscore for 2007-10-39
# No boxscore found for date 20071040
# Successfully scraped boxscore for 2007-10-40
# No boxscore found for date 20071041
# Successfully scraped boxscore for 2007-10-41
# No boxscore found for date 20071042
# Successfully scraped boxscore for 2007-10-42
# No boxscore found for date 20071043
# Successfully scraped boxscore for 2007-10-43
# No boxscore found for date 20071044
# Successfully scraped boxscore for 2007-10-44
# No boxscore found for date 20071045
# Successfully scraped boxscore for 2007-10-45
# No boxscore found for date 20071046
# Successfully scraped boxscore for 2007-10-46
# No boxscore found for date 20071047
# Successfully scraped boxscore for 2007-10-47
# No boxscore found for date 20071048
# Successfully scraped boxscore for 2007-10-48
# No boxscore found for date 20071049
# Successfully scraped boxscore for 2007-10-49
# No boxscore found for date 20071050
# Successfully scraped boxscore for 2007-10-50
# No boxscore found for date 20071051
# Successfully scraped boxscore for 2007-10-51
# No boxscore found for date 20071052
# Successfully scraped boxscore for 2007-10-52
# No boxscore found for date 20071053
# Successfully scraped boxscore for 2007-10-53
# No boxscore found for date 20071054
# Successfully scraped boxscore for 2007-10-54
# No boxscore found for date 20071055
# Successfully scraped boxscore for 2007-10-55
# No boxscore found for date 20071056
# Successfully scraped boxscore for 2007-10-56
# No boxscore found for date 20071057
# Successfully scraped boxscore for 2007-10-57
# No boxscore found for date 20071058
# Successfully scraped boxscore for 2007-10-58
# No boxscore found for date 20071059
# Successfully scraped boxscore for 2007-10-59
# No boxscore found for date 20071060
# Successfully scraped boxscore for 2007-10-60
# No boxscore found for date 20071061
# Successfully scraped boxscore for 2007-10-61
# No boxscore found for date 20071062
# Successfully scraped boxscore for 2007-10-62
# No boxscore found for date 20071063
# Successfully scraped boxscore for 2007-10-63
# No boxscore found for date 20071064
# Successfully scraped boxscore for 2007-10-64
# No boxscore found for date 20071065
# Successfully scraped boxscore for 2007-10-65
# No boxscore found for date 20071066
# Successfully scraped boxscore for 2007-10-66
# No boxscore found for date 20071067
# Successfully scraped boxscore for 2007-10-67
# No boxscore found for date 20071068
# Successfully scraped boxscore for 2007-10-68
# No boxscore found for date 20071069
# Successfully scraped boxscore for 2007-10-69
# No boxscore found for date 20071070
# Successfully scraped boxscore for 2007-10-70
# No boxscore found for date 20071071
# Successfully scraped boxscore for 2007-10-71
# No boxscore found for date 20071072
# Successfully scraped boxscore for 2007-10-72
# No boxscore found for date 20071073
# Successfully scraped boxscore for 2007-10-73
# No boxscore found for date 20071074
# Successfully scraped boxscore for 2007-10-74
# No boxscore found for date 20071075
# Successfully scraped boxscore for 2007-10-75
# No boxscore found for date 20071076
# Successfully scraped boxscore for 2007-10-76
# No boxscore found for date 20071077
# Successfully scraped boxscore for 2007-10-77
# No boxscore found for date 20071078
# Successfully scraped boxscore for 2007-10-78
# No boxscore found for date 20071079
# Successfully scraped boxscore for 2007-10-79
# No boxscore found for date 20071080
# Successfully scraped boxscore for 2007-10-80
# No boxscore found for date 20071081
# Successfully scraped boxscore for 2007-10-81
# No boxscore found for date 20071082
# Successfully scraped boxscore for 2007-10-82
# No boxscore found for date 20071083
# Successfully scraped boxscore for 2007-10-83
# No boxscore found for date 20071084
# Successfully scraped boxscore for 2007-10-84
# No boxscore found for date 20071085
# Successfully scraped boxscore for 2007-10-85
# No boxscore found for date 20071086
# Successfully scraped boxscore for 2007-10-86
# No boxscore found for date 20071087
# Successfully scraped boxscore for 2007-10-87
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/nx/50qt6bg15q70844qzhxhmsmm0000gn/T/ipykernel_37168/3005552472.py in <module>
#       3         for day in range(1, 100):
#       4             try:
# ----> 5                 boxscore_scrape(year,month,day)
#       6                 print(f"Successfully scraped boxscore for {year}-{month}-{day}")
#       7
#
# /var/folders/nx/50qt6bg15q70844qzhxhmsmm0000gn/T/ipykernel_37168/3999034307.py in boxscore_scrape(year, month, day)
#       6         #f"{year}{month}{str(day).rjust(2, '0')}"
#       7         url = 'https://bsnpr.com/juegos/juego?r=BS' + str(date_str)
# ----> 8         response = requests.get(url)
#       9         soup = BeautifulSoup(response.content, 'html.parser')
#      10
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     721             # Redirect resolving generator.
#     722             gen = self.resolve_redirects(r, request, **kwargs)
# --> 723             history = [resp for resp in gen]
#     724         else:
#     725             history = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in <listcomp>(.0)
#     721             # Redirect resolving generator.
#     722             gen = self.resolve_redirects(r, request, **kwargs)
# --> 723             history = [resp for resp in gen]
#     724         else:
#     725             history = []
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     264             else:
#     265
# --> 266                 resp = self.send(
#     267                     req,
#     268                     stream=stream,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url = 'https://bsnpr.com/juegos/juego?r=BS20201067'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

tables = soup.findAll("table", class_="tabla_stats")
#extract the date, time, and game id form the first row 
date_time, game_id = [cell.text.strip() for cell in tables.findAll("th", width="200")]
date, time = date_time.split()

#create a DataFrame with the extracted data
df = pd.DataFrame({'Date': [date], 'Time': [time], 'Game ID': [game_id]})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-17d4735ff06b> in <module>
#       5 tables = soup.findAll("table", class_="tabla_stats")
#       6 #extract the date, time, and game id form the first row
# ----> 7 date_time, game_id = [cell.text.strip() for cell in tables.findAll("th", width="200")]
#       8 date, time = date_time.split()
#       9
#
# ~/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    2252         """Raise a helpful exception to explain a common code fix."""
#    2253         raise AttributeError(
# -> 2254             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2255         )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
print(tables)
# Out:
# [<table class="table tabla_stats" width="100%">
# <tr>
# <td width="25%"><img src="/images/bsn.gif" width="80"/></td>
# <td align="center" width="50%"><b>BALONCESTO SUPERIOR NACIONAL<br/>
#               TEMPORADA 2020</b></td>
# <td align="right" width="25%"><img src="/images/aombprlogo.gif" width="80"/></td>
# </tr>
# </table>, <table class="table tabla_stats" width="100%">
# <tr>
# <th width="200">11/11/2020 3:00:00 PM</th>
# <th><div align="center">1st</div></th>
# <th><div align="center">2nd</div></th>
# <th><div align="center">3rd</div></th>
# <th><div align="center">4th</div></th>
# <th><div align="center">TOTAL</div></th>
# </tr>
# <tr class="border_abajo_1">
# <td class="score_border_abajo_r">
#                     Aguada
#                     </td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center"><span class="score_border_abajo_r">
#                     0
#                     </span></div></td>
# </tr>
# <tr>
# <td class="score_border_abajo_r"><b>
# <span class="ganador">
#                       Fajardo
#                       </span>
# </b></td>
# <td class="score_border_abajo"><div align="center">20</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center">0</div></td>
# <td class="score_border_abajo"><div align="center"><b>
# <span class="ganador">
#                       20
#                       </span>
# </b></div></td>
# </tr>
# <tr>
# <td class="score_border_r" height="30"><div align="right"></div></td>
# <td> </td>
# <td> </td>
# <td> </td>
# <td> </td>
# <td> </td>
# </tr>
# </table>, <table class="table tabla_stats table-th-rojo" width="100%">
# <tr bgcolor="silver">
# <th bgcolor="#ffffff" colspan="3"></th>
# <th align="center" colspan="3">2 Points</th>
# <th align="center" colspan="3">3 Points</th>
# <th align="center" colspan="3">Free Throws</th>
# <th align="center" colspan="3">Rebounds</th>
# <th bgcolor="#ffffff" colspan="10"></th>
# </tr>
# <tr>
# <th></th>
# <th>Name</th>
# <th>Min</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>O</th>
# <th>D</th>
# <th>To</th>
# <th>AS</th>
# <th>PF</th>
# <th>TO</th>
# <th>ST</th>
# <th>BS</th>
# <th>PTS</th>
# </tr>
# <tr class="alternar1">
# <td></td>
# <td><div align="right"><strong>Totals:</strong></div></td>
# <td><div align="center"></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# </tr>
# </table>, <table class="table tabla_stats" width="100%">
# <tr bgcolor="silver">
# <th bgcolor="#ffffff" colspan="3"></th>
# <th align="center" colspan="3">2 Points</th>
# <th align="center" colspan="3">3 Points</th>
# <th align="center" colspan="3">Free Throws</th>
# <th align="center" colspan="3">Rebounds</th>
# <th bgcolor="#ffffff" colspan="10"></th>
# </tr>
# <tr>
# <th></th>
# <th>Name</th>
# <th>Min</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>O</th>
# <th>D</th>
# <th>To</th>
# <th>AS</th>
# <th>PF</th>
# <th>TO</th>
# <th>ST</th>
# <th>BS</th>
# <th>PTS</th>
# </tr>
# <tr class="alternar1">
# <td></td>
# <td><div align="right"><strong>Totals:</strong></div></td>
# <td><div align="center"></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>
#
#           0%
#
#         </strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# <td><div align="center"><strong>0</strong></div></td>
# </tr>
# </table>]
