# %%
import pandas as pd 
import csv

# %%
df = pd.read_csv('Goat_results.csv')

# %%
df
# Out:
#        Simulated Games:  LeBron wins:  Jordan wins:  LJ WIN prob  MJ WIN prob  \
# 0                     1             1             0     1.000000     0.000000
# 1                     2             2             0     1.000000     0.000000
# 2                     3             3             0     1.000000     0.000000
# 3                     4             4             0     1.000000     0.000000
# 4                     5             5             0     1.000000     0.000000
# ...                 ...           ...           ...          ...          ...
# 19995             19996         11462          8534     0.573215     0.426785
# 19996             19997         11462          8535     0.573186     0.426814
# 19997             19998         11463          8535     0.573207     0.426793
# 19998             19999         11464          8535     0.573229     0.426771
# 19999             20000         11464          8536     0.573200     0.426800
#
# ...

# %%
df['Winner'] = df.apply(lambda row: 'LeBron' if row['Lebron Pts'] > row['MJ pts'] else 'Jordan', axis=1)
df.tail(7)
# Out:
#        Simulated Games:  LeBron wins:  Jordan wins:  LJ WIN prob  MJ WIN prob  \
# 19993             19994         11461          8533     0.573222     0.426778
# 19994             19995         11462          8533     0.573243     0.426757
# 19995             19996         11462          8534     0.573215     0.426785
# 19996             19997         11462          8535     0.573186     0.426814
# 19997             19998         11463          8535     0.573207     0.426793
# 19998             19999         11464          8535     0.573229     0.426771
# 19999             20000         11464          8536     0.573200     0.426800
#
#        Lebron Pts     MJ pts  Lebron score  jordan score  Lebron(PPG)  ...  \
# 19993   11.515700   3.883931     -2.004038     17.230767     1.182893  ...
# 19994    8.181182   3.260414      8.165924      0.449310     1.014337  ...
# 19995   12.248789  12.886736     -0.101771      6.556822     1.432878  ...
# ...

# %%
df.to_csv('Goat_results.csv', index=False)
