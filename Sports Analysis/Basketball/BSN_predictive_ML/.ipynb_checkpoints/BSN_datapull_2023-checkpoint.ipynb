# %%
# Importing the necessary modules. 
import os
import csv
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_boxscore = 'https://bsnpr.com/juegos/juego?r=BS20221198'
response = requests.get(url_boxscore)
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find_all("table", class_="tabla_stats")

# %%
import requests
from bs4 import BeautifulSoup

url_boxscore = 'https://bsnpr.com/juegos/juego?r=BS20221198'
response = requests.get(url_boxscore)
soup = BeautifulSoup(response.content, 'html.parser')

# Find the table in the HTML page
# This page presents the box score
table_boxscore = soup.find_all("table", class_="tabla_stats")[1]
# Home team
table_hometeam = soup.find_all("table", class_="tabla_stats")[2]
# Away team
table_awayteam = soup.find_all("table", class_="tabla_stats")[3]


table_hometeam
# Out:
# <table class="table tabla_stats table-th-rojo" width="100%">
# <tr bgcolor="silver">
# <th bgcolor="#ffffff" colspan="3"></th>
# <th align="center" colspan="3">2 Points</th>
# <th align="center" colspan="3">3 Points</th>
# <th align="center" colspan="3">Free Throws</th>
# <th align="center" colspan="3">Rebounds</th>
# <th bgcolor="#ffffff" colspan="10"></th>
# </tr>
# <tr>
# <th></th>
# <th>Name</th>
# <th>Min</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>M</th>
# <th>A</th>
# <th>%</th>
# <th>O</th>
# <th>D</th>
# <th>To</th>
# <th>AS</th>
# <th>PF</th>
# <th>TO</th>
# <th>ST</th>
# <th>BS</th>
# <th>PTS</th>
# </tr>
# <tr>
# <td>0</td>
# <td>Mojica, Sammy</td>
# <td><div align="center">11:49</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">
#             0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# </tr>
# <tr>
# <td>1</td>
# <td>Thompson Jr., Stephen</td>
# <td><div align="center">29:20</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">
#             60%
#
#         </div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">
#             67%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">
#             0%
#
#         </div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">18</div></td>
# </tr>
# <tr>
# <td>2</td>
# <td>Gonzalez, Javier</td>
# <td><div align="center">14:46</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">
#             0%
#
#         </div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">
#             50%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">3</div></td>
# </tr>
# <tr>
# <td>7</td>
# <td>Duran, Cliff</td>
# <td><div align="center">10:49</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">6</div></td>
# </tr>
# <tr>
# <td>8</td>
# <td>Wiley, Jacob</td>
# <td><div align="center">14:54</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">
#             80%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">8</div></td>
# </tr>
# <tr>
# <td>10</td>
# <td>Doolittle, Kristian</td>
# <td><div align="center">30:46</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">
#             50%
#
#         </div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">
#             80%
#
#         </div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">7</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">16</div></td>
# </tr>
# <tr>
# <td>13</td>
# <td>Rodriguez, Angel Daniel</td>
# <td><div align="center">28:47</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">
#             75%
#
#         </div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">5</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">7</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">24</div></td>
# </tr>
# <tr>
# <td>18</td>
# <td>Pérez, Owen</td>
# <td><div align="center">3:06</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">
#             67%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">4</div></td>
# </tr>
# <tr>
# <td>20</td>
# <td>Negron, Alexis J.</td>
# <td><div align="center">3:06</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">
#             0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# </tr>
# <tr>
# <td>22</td>
# <td>Santiago, Jr., Benito</td>
# <td><div align="center">18:56</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">
#             33%
#
#         </div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">11</div></td>
# </tr>
# <tr>
# <td>28</td>
# <td>Romero, Ismael</td>
# <td><div align="center">21:28</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">
#             50%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">3</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">
#             50%
#
#         </div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">6</div></td>
# <td><div align="center">7</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">4</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">7</div></td>
# </tr>
# <tr>
# <td>31</td>
# <td>Martinez, Giovanny</td>
# <td><div align="center">2:27</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# </tr>
# <tr>
# <td>33</td>
# <td>Cuascut, Luis D</td>
# <td><div align="center">9:46</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">
#             100%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">
#
#           0%
#
#         </div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">2</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">1</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">0</div></td>
# <td><div align="center">2</div></td>
# </tr>
# <tr class="alternar1">
# <td></td>
# <td><div align="right"><strong>Totals:</strong></div></td>
# <td><div align="center"></div></td>
# <td><div align="center"><strong>17</strong></div></td>
# <td><div align="center"><strong>28</strong></div></td>
# <td><div align="center"><strong>
#             61%
#
#         </strong></div></td>
# <td><div align="center"><strong>18</strong></div></td>
# <td><div align="center"><strong>28</strong></div></td>
# <td><div align="center"><strong>
#             64%
#
#         </strong></div></td>
# <td><div align="center"><strong>11</strong></div></td>
# <td><div align="center"><strong>16</strong></div></td>
# <td><div align="center"><strong>
#             69%
#
#         </strong></div></td>
# <td><div align="center"><strong>4</strong></div></td>
# <td><div align="center"><strong>23</strong></div></td>
# <td><div align="center"><strong>27</strong></div></td>
# <td><div align="center"><strong>24</strong></div></td>
# <td><div align="center"><strong>26</strong></div></td>
# <td><div align="center"><strong>16</strong></div></td>
# <td><div align="center"><strong>9</strong></div></td>
# <td><div align="center"><strong>2</strong></div></td>
# <td><div align="center"><strong>99</strong></div></td>
# </tr>
# </table>

# %%
# extract the team names and scores from the table_boxscore
team_names = []
team_scores = []
for row in table_boxscore.findAll("tr")[1:]:
    cols = row.findAll("td")
    team_names.append(cols[0].text.strip())
    team_scores.append(cols[-1].text.strip())
    
# Extract the table data
table_data = []
for row in table_boxscore.findAll("tr")[1:]:
    cols = row.findAll("td")[1:-1]
    row_data = [col.text.strip() for col in cols]
    table_data.append(row_data)


# Create a DataFrame from the table data 
df_table = pd.DataFrame(table_data, columns=['1Q', '2Q', '3Q', '4Q'])

# Create a DataFrame for the team names and scores 
df_team = pd.DataFrame({'Team': team_names, 'Score': team_scores})

# Concatenate the two DataFrames
df = pd.concat([df_team, df_table], axis=1)
df
# Out:
#            Team Score  1Q  2Q  3Q  4Q
# 0       Bayamon    99  19  19  31  30
# 1  Quebradillas    79  16  17  21  25
# 2

# %%
# Extract the table data fro the home team
table_data_home = []
for row in table_hometeam.findAll("tr")[1:]:
    cols = row.findAll("td")
    row_data = [col.text.strip() for col in cols]
    table_data_home.append(row_data)
    

# Create a DataFrame for the home team stats
df_home = pd.DataFrame(table_data_home, columns=['','Name', 'Min', 'M', 'A', 'FG%', 'M', 'A', '3P%', 'M', 'A', 'FT%', 'O', 'D', 'T', 'AS', 'PF', 'TO', 'ST', 'BS', 'PTS'])

# add a new column team with the value of the data frame earlier
df_home['Team'] = team_names[0]

# Remove the empty column  
#df_home = df_home.drop(columns=['']).iloc[1:]

# add a prefix to the column names of df_home 
df_home.columns = ['home_' + col if col != '' else 'home_Stat' for col in df_home.columns]

# Extract the table data for the away team
table_data_away = []
for row in table_awayteam.findAll("tr")[1:]:
    cols = row.findAll("td")
    row_data = [col.text.strip() for col in cols]
    table_data_away.append(row_data)
    
# Create a DataFrame for teh away team stats
df_away = pd.DataFrame(table_data_away, columns=['','Name', 'Min', ' M', 'A', 'FG%', 'M', 'A', '3P%', 'M', 'A', 'FT%', 'O', 'D', 'T', 'AS', 'PF', 'TO', 'ST', 'BS', 'PTS'])
df_away['Team'] = team_names[1]
df_away.columns = ['away_' + col if col != '' else 'away_Stat' for col in df_away.columns]

# Remove the empty column
#df_away = df_away.drop(columns=['']).iloc[1:]


print(df_home.index)
print(df_away.index)

# Concat both df 
game_df = pd.concat([df_home, df_away], axis=0)

# 

# Drop the first row
#game_df = game_df.drop(0)

# Reset the index
game_df = game_df.reset_index(drop=True)
print(game_df.index)
game_df
# Out:
# RangeIndex(start=0, stop=15, step=1)
# RangeIndex(start=0, stop=13, step=1)
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[132], line 41
#      38 print(df_away.index)
#      40 # Concat both df
# ---> 41 game_df = pd.concat([df_home, df_away], axis=0)
#      43 #
#      44
#      45 # Drop the first row
#      46 #game_df = game_df.drop(0)
#      47
#      48 # Reset the index
#      49 game_df = game_df.reset_index(drop=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/concat.py:612, in _Concatenator.get_result(self)
#     610         obj_labels = obj.axes[1 - ax]
#     611         if not new_labels.equals(obj_labels):
# --> 612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
#     616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:3904, in Index.get_indexer(self, target, method, limit, tolerance)
#    3901 self._check_indexing_method(method, limit, tolerance)
#    3903 if not self._index_as_unique:
# -> 3904     raise InvalidIndexError(self._requires_unique_msg)
#    3906 if len(target) == 0:
#    3907     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %% [markdown]
# # BSN calendar pull
#
# 1. Define a list of team numbers and names:

# %%
# Define a list of team numbers and names

teams = [
    (1, 'Cangrejeros', 'Santurce'),
    (2, 'Capitanes', 'Arecibo'),
    (3, 'Atleticos', 'San German'),
    (5, 'Leones', 'Ponce'),
    (6, 'Piratas', 'Quebradillas'),
    (9, 'Vaqueros', 'Bayamon'),
    (10, 'Gigantes', 'Carolina'),
    (12, 'Indios', 'Mayaguez'),
    (14, 'Mets', 'Guaynabo'),
    (15, 'Cariduros', 'Fajardo'),
    (73, 'Grises', 'Humacao'),
    (79, 'Osos', 'Manati')
]

# Define the range of years, months, and days to scrape
years = range(2021, 2024)
months = range(1, 13)
days = range(1, 100)

# Loop over all possible dates and URLs
for year in years:
    for month in months:
        for day in days:
            # Construct the URL for the current date
            date_str = f"{year}{month:02d}{day:02d}"
            url_boxscore = 'https://bsnpr.com/juegos/juego?r=BS{date_str}'
            
            # Make a request to the current URL and check if it returns a 200 status code
            response = requests.get(url_boxscore)
            if response.status_code == 200:
                print(f'Processing date: {date_str}')
                
                # Parse the HTML content of the page usingg BeautifulSoup
                soup = BeautifulSoup(response.content, 'html.parser')
                
                # Find all divs with class "table tabla_stats"
                tables = soup.find(class_="table tabla_stats")
                # This page presents the box score
                table_boxscore = soup.find_all("table", class_="tabla_stats")[1]
# Home team
                table_hometeam = soup.find_all("table", class_="tabla_stats")[2]
# Away team
                table_awayteam = soup.find_all("table", class_="tabla_stats")[3]



                team_names = []
                team_scores = []
                for row in table_boxscore.findAll("tr")[1:]:
                    cols = row.findAll("td")
                    team_names.append(cols[0].text.strip())
                    team_scores.append(cols[-1].text.strip())
    
# Extract the table data
                table_data = []
                for row in table_boxscore.findAll("tr")[1:]:
                    cols = row.findAll("td")[1:-1]
                    row_data = [col.text.strip() for col in cols]
                    table_data.append(row_data)


# Create a DataFrame from the table data 
                df_table = pd.DataFrame(table_data, columns=['1Q', '2Q', '3Q', '4Q'])

# Create a DataFrame for the team names and scores 
                df_team = pd.DataFrame({'Team': team_names, 'Score': team_scores})

# Concatenate the two DataFrames
                df = pd.concat([df_team, df_table], axis=1)
                
                print(f'Processing Box-Score for the date: {date_str}')
                
                
            
            else: 
                    print(f'No data found for date: {date_str}')

# %%
data
