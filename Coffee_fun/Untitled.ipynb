# %%
import os 
import pandas as pd
import csv

# %%
coffee = pd.read_csv('coffee_data.csv')
coffee
# Out:
#                                        name  price   country  \
# 0                                 Café 2150   9.50  products
# 1   Café Abuelo Domingo - Hacienda La Mocha  20.00  products
# 2                             Café Alquimia  28.00  products
# 3           Café Aromas del Campo - Gourmet  23.95  products
# 4           Café Aromas del Campo - Premium  15.00  products
# 5                          Café Baraka 24/7  14.95  products
# 6                             Café Don José  19.00  products
# 7                             Café Don Luis  22.00  products
# 8                    Café Don Luis - Borbón  24.95  products
# 9                            Café Don Pello   8.00  products
# 10          Café Don Pello - Tueste Barista  16.00  products
# 11        Café Don Pello Specialty - Jayuya  27.95  products
# 12         Café Don Pello Specialty - Yauco  20.00  products
# 13            Café Don Pello Specialty Pods  15.00  products
# ...
